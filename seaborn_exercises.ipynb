# %%
import pandas as pd
import numpy as np
from pydataset import data
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.1
# - What does the distribution of petal lengths look like?

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 40            5.0          3.5           1.3          0.3      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 52            6.9          3.1           4.9          1.5  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 98            5.1          2.5           3.0          1.1  versicolor

# %%
#Shape of the distribution
sns.histplot(data=df, x='petal_length', kde =True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# # 1.2
# - Is there a correlation between petal length and petal width?
#
# #### With a score of 0.962865 It is safe to say that there is a strong case for correlation

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.relplot(data=df, x='petal_length', y='petal_width', hue='species')

# %% [markdown]
# # 1.3
# - Would it be reasonable to predict species based on sepal width and sepal length?
# With a score of negative score we can say that it won't be reasonable

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.relplot(data=df, x='sepal_length', y='sepal_width', hue='species')

# %% [markdown]
# # 1.4
# - Which features would be best used to predict species?

# %%
sns.pairplot(data=df, hue='species')

# %%
#Correlation coefficient values less than +0.8 or greater than -0.8 are not considered significant.
corr = df.corr()
corr > .80
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length          True        False          True         True
# sepal_width          False         True         False        False
# petal_length          True        False          True         True
# petal_width           True        False          True         True

# %% [markdown]
# # Part II

# %% [markdown]
# # 2.1
# Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
#
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
df = sns.load_dataset('anscombe')
df.sample(5)
# Out:
#    dataset     x     y
# 0        I  10.0  8.04
# 36      IV   8.0  8.84
# 38      IV   8.0  7.04
# 14      II   9.0  8.77
# 32     III   5.0  5.73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
df.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.relplot(data = df, x = 'x', y = 'y', col = 'dataset', hue='dataset')

# %% [markdown]
# # 2.2
# Load the InsectSprays dataset and read it's documentation.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = data('InsectSprays')
data('InsectSprays', show_doc = True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
df.sample(5)
# Out:
#     count spray
# 51      3     E
# 26      1     C
# 18     14     B
# 11     14     A
# 37      3     D

# %% [markdown]
# ### Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
sns.boxplot(data = df, x = 'spray', y = 'count')
plt.title('Insect sprays effectiveness')
# Out:
# Text(0.5, 1.0, 'Insect sprays effectiveness')

# %% [markdown]
# # 2.3
# Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than seaborn. Create visualizations to answer the following questions:

# %%
df = data('swiss')
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %% [markdown]
# #### Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
df.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
df['is_catholic'] = df.Catholic > 50
df.tail()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Val de Ruz         77.6         37.6           15          7      4.97
# ValdeTravers       67.6         18.7           25          7      8.65
# V. De Geneve       35.0          1.2           37         53     42.34
# Rive Droite        44.7         46.6           16         29     50.43
# Rive Gauche        42.8         27.7           22         29     58.33
#
#               Infant.Mortality  is_catholic
# Val de Ruz                20.0        False
# ValdeTravers              19.5        False
# V. De Geneve              18.0        False
# Rive Droite               18.2         True
# Rive Gauche               19.3         True

# %% [markdown]
# #### Does whether or not a province is Catholic influence fertility?

# %%
sns.boxplot(data=df, x = 'is_catholic', y = 'Fertility')
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %%
sns.pairplot(data=df, hue='is_catholic')

# %% [markdown]
# #### What measure correlates most strongly with fertility?

# %%
df.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.402813     0.410503    -0.597861  -0.154677  0.961723
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.402813
# Agriculture              -0.060859     0.410503
# Examination              -0.114022    -0.597861
# Education                -0.099322    -0.154677
# Catholic                  0.175496     0.961723
# Infant.Mortality          1.000000     0.166081
# ...

# %% [markdown]
# # 2.4
# Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
def get_db_url(db):
    from env import user, password, host
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
url = get_db_url('chipotle')
sql = "SELECT * FROM orders"
orders = pd.read_sql(sql, url)
orders.sample(5)
# Out:
#         id  order_id  quantity                     item_name  \
# 241    242       105         2               Chicken Burrito
# 3586  3587      1438         1                  Chicken Bowl
# 240    241       104         1  Chips and Fresh Tomato Salsa
# 929    930       383         1           Chips and Guacamole
# 1587  1588       642         1           Carnitas Soft Tacos
#
#                                                                              choice_description  \
# 241               [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]
# 3586  [Roasted Chili Corn Salsa (Medium), [Black Beans, Rice, Fajita Veggies, Cheese, Sour C...
# 240                                                                                         nan
# 929                                                                                         nan
# 1587                                              [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
#
#      item_price
# ...

# %%
orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')
# Out:
# <ipython-input-27-04eaffc95985>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')

# %%
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
top = orders.groupby('item_name').quantity.sum().sort_values(ascending=False).head(4)
top
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
top = pd.DataFrame(top)
top
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506
# Steak Burrito             386

# %%
top_l = list(top.index)
# Out:
# ['Chicken Bowl', 'Chicken Burrito', 'Chips and Guacamole', 'Steak Burrito']

# %%
price = orders.groupby('item_name').item_price.mean()
price = pd.DataFrame(price)
price[price['item_price']  ]
# Out:
#                                        item_price
# item_name
# 6 Pack Soft Drink                        6.610185
# Barbacoa Bowl                           10.187273
# Barbacoa Burrito                         9.832418
# Barbacoa Crispy Tacos                   10.928182
# Barbacoa Salad Bowl                     10.640000
# Barbacoa Soft Tacos                     10.018400
# Bottled Water                            1.867654
# Bowl                                    14.800000
# Burrito                                  7.400000
# Canned Soda                              1.320577
# Canned Soft Drink                        1.457641
# Carnitas Bowl                           10.833971
# Carnitas Burrito                        10.132712
# Carnitas Crispy Tacos                   11.137143
# Carnitas Salad                           8.990000
# Carnitas Salad Bowl                     11.056667
# Carnitas Soft Tacos                      9.398500
# Chicken Bowl                            10.113953
# ...

# %%
top.merge(price, left_on='item_name', right_on='item_name')
# Out:
#                      quantity  item_price
# item_name
# Chicken Bowl              761   10.113953
# Chicken Burrito           591   10.082857
# Chips and Guacamole       506    4.595073
# Steak Burrito             386   10.465842

# %%
final['revenue'] = final.quantity * final.item_price

# %%
final
# Out:
#                      quantity  item_price      revenue
# item_name
# Chicken Bowl              761   10.113953  7696.718361
# Chicken Burrito           591   10.082857  5958.968571
# Chips and Guacamole       506    4.595073  2325.106973
# Steak Burrito             386   10.465842  4039.815163

# %%
sns.barplot(data=final, x='item_name', y='revenue')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-38fbc972e95e> in <module>
# ----> 1 sns.barplot(data=final, x='item_name', y='revenue')
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
# ...

# %%
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-c027f009795f> in <module>
# ----> 1 sns.barplot(final)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# # 5
# Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
df = data('sleepstudy')
df
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Reaction  180 non-null    float64
#  1   Days      180 non-null    int64
#  2   Subject   180 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 5.6 KB

# %%
sns.lineplot(data = df, x = 'Days', y = 'Reaction',  hue = 'Subject')
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>
